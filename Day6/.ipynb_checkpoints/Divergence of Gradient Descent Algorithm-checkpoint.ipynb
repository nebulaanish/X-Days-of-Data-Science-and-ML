# %% [markdown]
# # Divergence of Gradient Descent Algorithm

# %% [markdown]
# - $ h(x) = x^5 -2x^4 +2 $

# %%
def h(x):
    return x**5-2*x**4 +2
def dh(x):
    return 5*x**4 -8*x**3

# %%
# import section
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# sample points
x_3 = np.linspace(-2.5,2.5,1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # sample points
# ----> 2 x_3 = np.linspace(-2.5,2.5,1000)
#
# NameError: name 'np' is not defined

# %%
#
