# %% [markdown]
# # Gradient Descent and Advanced Functions

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Function Example
#
# - $ g(x) = x^4 -4x^2 + 5 $

# %%
# function definition
def g(x):
    return x**4 - 4*x**2 + 5
def dg(x):
    return 4*x**3 - 8*x

# %%
# Sample points creation
x_1 = np.linspace(-3,3,100)

# %%
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
plt.xlim(-3,3)
plt.ylim(0,20)
plt.plot(x_1,g(x_1))
plt.grid()

plt.subplot(1,2,2)
plt.plot(x_1,dg(x_1))
plt.ylim(-6,10)
plt.grid()

# %%
# Gradient Descent on this function

def gradient_descent(derivative_function, first_guess, step_multiplier=.01,precision=.001):
    new_x = first_guess
    difference = 100
    xlist = [new_x]
    dxlist = [derivative_function(new_x)]
    while(difference > precision):
        prev_x = new_x
        gradient = derivative_function(prev_x)
        new_x = prev_x - step_multiplier*gradient
        difference = abs(prev_x-new_x)
        xlist.append(new_x)
        dxlist.append(derivative_function(new_x))
        
    return new_x,gradient,xlist,dxlist
minima,gradient,xlist,dxlist = gradient_descent(dg,0)

#plot graphs
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
plt.plot(x_1,g(x_1))
plt.scatter(xlist,g(np.array(xlist)),s=100,color='red')
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.grid()
# print(type(x_1))
# print(type(np.array(xlist)))
# print(type(xlist))
# print(type(g(np.array(xlist))))


plt.subplot(1,2,2)
plt.plot(x_1,dg(x_1))
plt.scatter(xlist,dxlist,color="red",s=100,alpha=.6)
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.grid()
